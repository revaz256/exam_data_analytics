# %%
import pandas as pd

# %%
df = pd.read_csv('data/survey_results_public.csv', index_col = 'Respondent')

# %% [markdown]
# df

# %%
pd.set_option('display.max_columns', 61)
pd.set_option('display.max_rows', 61)

# %%
schema_df = pd.read_csv('data/survey_results_schema.csv', index_col = 'Column')

# %%
schema_df.tail(10)
# Out:
#                                                              QuestionText
# Column
# SurveyEase              How easy or difficult was this survey to compl...
# SurveyLength            How do you feel about the length of the survey...
# Trans                                                Are you transgender?
# UndergradMajor                      What was your primary field of study?
# WebframeDesireNextYear  Which web frameworks have you done extensive d...
# WebframeWorkedWith      Which web frameworks have you done extensive d...
# WelcomeChange           Compared to last year, how welcome do you feel...
# WorkWeekHrs             On average, how many hours per week do you wor...
# YearsCode               Including any education, how many years have y...
# YearsCodePro            NOT including education, how many years have y...

# %%
df.head()
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1                              I am a developer by profession      Yes   NaN
# 2                              I am a developer by profession       No   NaN
# 3                                 I code primarily as a hobby      Yes   NaN
# 4                              I am a developer by profession      Yes  25.0
# 5           I used to be a developer by profession, but no...      Yes  31.0
#
#            Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# Respondent
# 1                  13  Monthly        NaN            NaN             Germany
# 2                  19      NaN        NaN            NaN      United Kingdom
# 3                  15      NaN        NaN            NaN  Russian Federation
# 4                  18      NaN        NaN            NaN             Albania
# 5                  16      NaN        NaN            NaN       United States
#
# ...

# %%
df['Age']
# Out:
# Respondent
# 1         NaN
# 2         NaN
# 3         NaN
# 4        25.0
# 5        31.0
#          ...
# 64858     NaN
# 64867     NaN
# 64898     NaN
# 64925     NaN
# 65112     NaN
# Name: Age, Length: 64461, dtype: float64

# %%
type(df['Age'])
# Out:
# pandas.core.series.Series

# %%
df.Age
# Out:
# Respondent
# 1         NaN
# 2         NaN
# 3         NaN
# 4        25.0
# 5        31.0
#          ...
# 64858     NaN
# 64867     NaN
# 64898     NaN
# 64925     NaN
# 65112     NaN
# Name: Age, Length: 64461, dtype: float64

# %%
df[['Age', 'Age1stCode']] #filtered data frame
# Out:
#              Age Age1stCode
# Respondent
# 1            NaN         13
# 2            NaN         19
# 3            NaN         15
# 4           25.0         18
# 5           31.0         16
# ...          ...        ...
# 64858        NaN         16
# 64867        NaN        NaN
# 64898        NaN        NaN
# 64925        NaN        NaN
# 65112        NaN        NaN
#
# [64461 rows x 2 columns]

# %%
df.columns
# Out:
# Index(['MainBranch', 'Hobbyist', 'Age', 'Age1stCode', 'CompFreq', 'CompTotal',
#        'ConvertedComp', 'Country', 'CurrencyDesc', 'CurrencySymbol',
#        'DatabaseDesireNextYear', 'DatabaseWorkedWith', 'DevType', 'EdLevel',
#        'Employment', 'Ethnicity', 'Gender', 'JobFactors', 'JobSat', 'JobSeek',
#        'LanguageDesireNextYear', 'LanguageWorkedWith',
#        'MiscTechDesireNextYear', 'MiscTechWorkedWith',
#        'NEWCollabToolsDesireNextYear', 'NEWCollabToolsWorkedWith', 'NEWDevOps',
#        'NEWDevOpsImpt', 'NEWEdImpt', 'NEWJobHunt', 'NEWJobHuntResearch',
#        'NEWLearn', 'NEWOffTopic', 'NEWOnboardGood', 'NEWOtherComms',
#        'NEWOvertime', 'NEWPurchaseResearch', 'NEWPurpleLink', 'NEWSOSites',
#        'NEWStuck', 'OpSys', 'OrgSize', 'PlatformDesireNextYear',
#        'PlatformWorkedWith', 'PurchaseWhat', 'Sexuality', 'SOAccount',
#        'SOComm', 'SOPartFreq', 'SOVisitFreq', 'SurveyEase', 'SurveyLength',
# ...

# %%
df.iloc[0]
# Out:
# MainBranch                                         I am a developer by profession
# Hobbyist                                                                      Yes
# Age                                                                           NaN
# Age1stCode                                                                     13
# CompFreq                                                                  Monthly
# CompTotal                                                                     NaN
# ConvertedComp                                                                 NaN
# Country                                                                   Germany
# CurrencyDesc                                                        European Euro
# CurrencySymbol                                                                EUR
# DatabaseDesireNextYear                                       Microsoft SQL Server
# ...

# %%
df.iloc[[0,1]]
# Out:
#                                 MainBranch Hobbyist  Age Age1stCode CompFreq  \
# Respondent
# 1           I am a developer by profession      Yes  NaN         13  Monthly
# 2           I am a developer by profession       No  NaN         19      NaN
#
#             CompTotal  ConvertedComp         Country    CurrencyDesc  \
# Respondent
# 1                 NaN            NaN         Germany   European Euro
# 2                 NaN            NaN  United Kingdom  Pound sterling
#
#            CurrencySymbol DatabaseDesireNextYear  \
# Respondent
# 1                     EUR   Microsoft SQL Server
# 2                     GBP                    NaN
#
#                                    DatabaseWorkedWith  \
# Respondent
# 1           Elasticsearch;Microsoft SQL Server;Oracle
# 2                                                 NaN
#
#                                                       DevType  \
# Respondent
# 1           Developer, desktop or enterprise applications;...
# ...

# %%
df.iloc[[0,1], 2]
# Out:
# Respondent
# 1   NaN
# 2   NaN
# Name: Age, dtype: float64

# %%
df.shape
# Out:
# (64461, 60)

# %%
df['Hobbyist'].value_counts()
# Out:
# Yes    50388
# No     14028
# Name: Hobbyist, dtype: int64

# %%
df['Sexuality'].value_counts()
# Out:
# Straight / Heterosexual                                  40118
# Bisexual                                                  1918
# Gay or Lesbian                                             978
# Bisexual;Straight / Heterosexual                           258
# Queer                                                      249
# Bisexual;Queer                                             191
# Gay or Lesbian;Queer                                        90
# Straight / Heterosexual;Queer                               56
# Bisexual;Gay or Lesbian                                     40
# Bisexual;Gay or Lesbian;Straight / Heterosexual;Queer       39
# Bisexual;Gay or Lesbian;Queer                               24
# Gay or Lesbian;Straight / Heterosexual                      13
# Bisexual;Straight / Heterosexual;Queer                      10
# Bisexual;Gay or Lesbian;Straight / Heterosexual              8
# Name: Sexuality, dtype: int64

# %%
schema_df
# Out:
#                                                                    QuestionText
# Column
# Respondent                    Randomized respondent ID number (not in order ...
# MainBranch                    Which of the following options best describes ...
# Hobbyist                                                Do you code as a hobby?
# Age                           What is your age (in years)? If you prefer not...
# Age1stCode                    At what age did you write your first line of c...
# CompFreq                       Is that compensation weekly, monthly, or yearly?
# CompTotal                     What is your current total compensation (salar...
# ConvertedComp                 Salary converted to annual USD salaries using ...
# Country                                                      Where do you live?
# CurrencyDesc                  Which currency do you use day-to-day? If your ...
# CurrencySymbol                Which currency do you use day-to-day? If your ...
# ...

# %%
schema_df.loc['Hobbyist', 'QuestionText']
# Out:
# 'Do you code as a hobby?'

# %%
schema_df.sort_index() # ascending=False inside parentheses if you want order to be Z-A instead of A-Z
# Out:
#                                                                    QuestionText
# Column
# Age                           What is your age (in years)? If you prefer not...
# Age1stCode                    At what age did you write your first line of c...
# CompFreq                       Is that compensation weekly, monthly, or yearly?
# CompTotal                     What is your current total compensation (salar...
# ConvertedComp                 Salary converted to annual USD salaries using ...
# Country                                                      Where do you live?
# CurrencyDesc                  Which currency do you use day-to-day? If your ...
# CurrencySymbol                Which currency do you use day-to-day? If your ...
# DatabaseDesireNextYear        Which database environments have you done exte...
# DatabaseWorkedWith            Which database environments have you done exte...
# DevType                       Which of the following describe you? Please se...
# ...

# %%
schema_df.sort_index(inplace=True) #permanently sorts the dataframe

# %%
high_salary = (df['ConvertedComp'] > 100000)

# %%
df.loc[high_salary, ['ConvertedComp','Country', 'Age', 'LanguageWorkedWith']]
# Out:
#             ConvertedComp         Country   Age  \
# Respondent
# 8                116000.0   United States  36.0
# 16               108576.0  United Kingdom  45.0
# 18              1260000.0   United States  32.0
# 41               106000.0   United States   NaN
# 42               130000.0   United States  32.0
# ...                   ...             ...   ...
# 65586            225000.0   United States   NaN
# 65589            150000.0   United States   NaN
# 65602            140000.0   United States   NaN
# 65604            150000.0   United States   NaN
# 65617            129718.0         Germany   NaN
#
#                                            LanguageWorkedWith
# Respondent
# 8                                                  Python;SQL
# 16          Bash/Shell/PowerShell;HTML/CSS;Java;JavaScript...
# 18                        Bash/Shell/PowerShell;HTML/CSS;Perl
# 41                                              C;C#;Java;SQL
# ...

# %%
countries = ['United States', 'India', 'Germany', 'Canada', 'United Kingdom']

# %%
filt = df['LanguageWorkedWith'].str.contains('Python', na=False)

# %%
df.loc[filt, 'LanguageWorkedWith']
# Out:
# Respondent
# 3                                 Objective-C;Python;Swift
# 8                                               Python;SQL
# 10                     HTML/CSS;Java;JavaScript;Python;SQL
# 13                                     C;JavaScript;Python
# 15        Bash/Shell/PowerShell;C;HTML/CSS;Java;Python;SQL
#                                ...
# 61561    Bash/Shell/PowerShell;HTML/CSS;JavaScript;Perl...
# 62391       C++;HTML/CSS;JavaScript;Python;Ruby;TypeScript
# 63077              C++;HTML/CSS;Java;JavaScript;Python;SQL
# 63640    Bash/Shell/PowerShell;C;C#;C++;HTML/CSS;Java;J...
# 64867    Assembly;Bash/Shell/PowerShell;C;C#;C++;Dart;G...
# Name: LanguageWorkedWith, Length: 25287, dtype: object

# %%
df.loc[filt]
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 3                                 I code primarily as a hobby      Yes   NaN
# 8                              I am a developer by profession      Yes  36.0
# 10                             I am a developer by profession      Yes  22.0
# 13          I am not primarily a developer, but I write co...      Yes  53.0
# 15                     I am a student who is learning to code      Yes   NaN
# ...                                                       ...      ...   ...
# 61561                                                     NaN      Yes  64.0
# 62391                                                     NaN      Yes   NaN
# 63077                                                     NaN      Yes   NaN
# 63640                                                     NaN      Yes   NaN
# 64867                                                     NaN      Yes   NaN
#
# ...

# %%
#df.columns =[x.lower() for x in df.columns]

# %%
#df.rename(columns={'first': 'first_name', 'last': 'last_name'}, inplace=True)

# %%
df.loc[2]
# Out:
# MainBranch                                         I am a developer by profession
# Hobbyist                                                                       No
# Age                                                                           NaN
# Age1stCode                                                                     19
# CompFreq                                                                      NaN
# CompTotal                                                                     NaN
# ConvertedComp                                                                 NaN
# Country                                                            United Kingdom
# CurrencyDesc                                                       Pound sterling
# CurrencySymbol                                                                GBP
# DatabaseDesireNextYear                                                        NaN
# ...

# %%
#to replace a row:
#df.loc[rowAsInt, 'nameOfColumn'] = newValue for column & row
#can adjust multiple columns by inserting a list i.e. ['nameOfFirstColumn', 'nameOfSecond', ...]
#you can also do df.loc[filt, 'nameOfColumn'] if you want to filter out specific rows to work with

# %%
#apply calls a function on every value in our series
# def update_country(country):
  #  return country.upper()
# df['country'].apply(update_country)

# OR if you want to use lambda for a simple function you can do something like

# df['country'].apply(lambda x: x.lower())

# %%
df.rename(columns={'ConvertedComp': 'SalaryUSD'}, inplace=True)
df
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1                              I am a developer by profession      Yes   NaN
# 2                              I am a developer by profession       No   NaN
# 3                                 I code primarily as a hobby      Yes   NaN
# 4                              I am a developer by profession      Yes  25.0
# 5           I used to be a developer by profession, but no...      Yes  31.0
# ...                                                       ...      ...   ...
# 64858                                                     NaN      Yes   NaN
# 64867                                                     NaN      Yes   NaN
# 64898                                                     NaN      Yes   NaN
# 64925                                                     NaN      Yes   NaN
# 65112                                                     NaN      Yes   NaN
#
# ...

# %%
df.head()
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1                              I am a developer by profession      Yes   NaN
# 2                              I am a developer by profession       No   NaN
# 3                                 I code primarily as a hobby      Yes   NaN
# 4                              I am a developer by profession      Yes  25.0
# 5           I used to be a developer by profession, but no...      Yes  31.0
#
#            Age1stCode CompFreq  CompTotal  SalaryUSD             Country  \
# Respondent
# 1                  13  Monthly        NaN        NaN             Germany
# 2                  19      NaN        NaN        NaN      United Kingdom
# 3                  15      NaN        NaN        NaN  Russian Federation
# 4                  18      NaN        NaN        NaN             Albania
# 5                  16      NaN        NaN        NaN       United States
#
# ...

# %%
df['Hobbyist']
# Out:
# Respondent
# 1        Yes
# 2         No
# 3        Yes
# 4        Yes
# 5        Yes
#         ...
# 64858    Yes
# 64867    Yes
# 64898    Yes
# 64925    Yes
# 65112    Yes
# Name: Hobbyist, Length: 64461, dtype: object

# %%
df['Hobbyist'].map({'Yes': True, 'No': False})
# Out:
# Respondent
# 1         True
# 2        False
# 3         True
# 4         True
# 5         True
#          ...
# 64858     True
# 64867     True
# 64898     True
# 64925     True
# 65112     True
# Name: Hobbyist, Length: 64461, dtype: object

# %%
df['Hobbyist'] = df['Hobbyist'].map({'Yes': True, 'No': False})
df
# if a column has more than just Yes & No values then use .replace instead of .map
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1                              I am a developer by profession     True   NaN
# 2                              I am a developer by profession    False   NaN
# 3                                 I code primarily as a hobby     True   NaN
# 4                              I am a developer by profession     True  25.0
# 5           I used to be a developer by profession, but no...     True  31.0
# ...                                                       ...      ...   ...
# 64858                                                     NaN     True   NaN
# 64867                                                     NaN     True   NaN
# 64898                                                     NaN     True   NaN
# 64925                                                     NaN     True   NaN
# 65112                                                     NaN     True   NaN
#
# ...

# %%
# to combine colums (only bracket notation, not .notation):
# df['full_name'] = df['first'] + ' ' + df['last']
# this creates the new column called full_name
# then to remove the first and last columns:
# df.drop(columns=['first', 'last'])

# %%
# to move backwards:
# df[['first', 'last']] = df['full_name'].str.split(' ', expand=True)
#creates 2 new rows called first & last

# %%
# to add a single row:
# df.append()

# df.append({'first': 'Tony'}), ignore_index=True
# creates a new row with the column value for first = 'Tony'
# rest of the columns are NaN

# %%
people = {
    'first': ['Tony', 'Steve'],
    'last': ['Stark', 'Rogers'],
    'email': ['ironman@avenge.com', 'cap@avenge.com']
}
df2 = pd.DataFrame(people)

# %%
df2
# Out:
#    first    last               email
# 0   Tony   Stark  ironman@avenge.com
# 1  Steve  Rogers      cap@avenge.com

# %%
df2.append(df2, ignore_index=True, sort=False)
# Out:
#    first    last               email
# 0   Tony   Stark  ironman@avenge.com
# 1  Steve  Rogers      cap@avenge.com
# 2   Tony   Stark  ironman@avenge.com
# 3  Steve  Rogers      cap@avenge.com

# %%
df2.drop(index=0)
df2
# Out:
#    first    last               email
# 0   Tony   Stark  ironman@avenge.com
# 1  Steve  Rogers      cap@avenge.com

# %%
# to remove a row using a filter:
filt = df2['last']=='Stark'
df2.drop(index=df2[filt].index)
# Out:
#    first    last           email
# 1  Steve  Rogers  cap@avenge.com

# %%
#df.sort_values(by='nameOfColumn', ascending=True or False)
#df.sort_values(by=['last_name', 'first_name'], ascending=True or False) #sorts in order from left to right
                                                                         #in this case by last name and then first name

# %%
#df.sort_values(by=['last_name', 'first_name'], ascending=[True, False]) #sorts last name in ascending order and first name
                                                                         #in descending order

# %%
#df.sort_index() #sorts the indecies after sorting values ex. sorting values might mean the row with index 3 goes above index 1
                 # so instead of the rows being 0 3 2 1 you can have them become 0 1 2 3 again after changing values

# %%
# if you just want to see the sorted column you can do df['last'].sort_values()

# %%
df.sort_values(by=['Country', 'SalaryUSD'], ascending=[True, False], inplace = True)

# %%
df[['Country', 'SalaryUSD']].head(50)
# Out:
#                 Country  SalaryUSD
# Respondent
# 65381       Afghanistan  1000000.0
# 65456       Afghanistan  1000000.0
# 62788       Afghanistan  1000000.0
# 38672       Afghanistan   231192.0
# 28374       Afghanistan   130000.0
# 63848       Afghanistan    23328.0
# 9839        Afghanistan    23328.0
# 51862       Afghanistan    20950.0
# 51509       Afghanistan    20220.0
# 44484       Afghanistan    18660.0
# 15422       Afghanistan    18000.0
# 2932        Afghanistan    16335.0
# 26540       Afghanistan    13992.0
# 57269       Afghanistan    10884.0
# 26775       Afghanistan     8016.0
# 30568       Afghanistan     5448.0
# 30522       Afghanistan     4668.0
# 28811       Afghanistan     4509.0
# 34969       Afghanistan     4356.0
# 26857       Afghanistan     2328.0
# 33878       Afghanistan     1860.0
# 35753       Afghanistan      780.0
# 18049       Afghanistan      109.0
# 35295       Afghanistan        0.0
# 8631        Afghanistan        NaN
# ...

# %%
df['SalaryUSD'].nlargest(10)
# Out:
# Respondent
# 54263    2000000.0
# 5725     2000000.0
# 43430    2000000.0
# 59279    2000000.0
# 46711    2000000.0
# 1793     2000000.0
# 3072     2000000.0
# 3045     2000000.0
# 1413     2000000.0
# 3261     2000000.0
# Name: SalaryUSD, dtype: float64

# %%
df.nlargest(10, 'SalaryUSD')
# Out:
#                                 MainBranch Hobbyist   Age  \
# Respondent
# 54263       I am a developer by profession     True  29.0
# 5725        I am a developer by profession    False  26.0
# 43430       I am a developer by profession     True  33.0
# 59279       I am a developer by profession     True   NaN
# 46711       I am a developer by profession     True   NaN
# 1793        I am a developer by profession     True  27.0
# 3072        I am a developer by profession     True  32.0
# 3045        I am a developer by profession     True  35.0
# 1413        I am a developer by profession     True  25.0
# 3261        I am a developer by profession     True  34.0
#
#                       Age1stCode CompFreq     CompTotal  SalaryUSD  \
# Respondent
# 54263                         10   Weekly  7.000000e+04  2000000.0
# 5725                          14  Monthly  1.800000e+05  2000000.0
# 43430                         17  Monthly  1.710000e+05  2000000.0
# ...

# %%
### working with dates and time series data

# %%
# df['Date'] = pd.to_datetime(df['Date'], format='%Y-%m-%d %I-%p') --> format in this example could be 2020-02-13 8-PM

# %%
# could also load csv like:
# d_parser = lambda x: pd.datetime.strptime(x, '%Y-%m-%d %I-%p')
# df = pd.read_csv('FileName', parse_dates=['Date'], date_parser = d_parser)

# %%
# df['Date'].dt.day_name() # gets day of the week for each row of the series
# or df.loc[0, 'Date'].day_name() to get the day of the week for a specific row

# %%
# has min() and max() functions

# %%
# can subtract max() and min() to find the Timedelta (dates between them)

# %%
# can filter data with > & < 

#or 

#df['2020-01' : '2020-02']

# %%
# .resample('D') # resamples data to daily basis
# ex: .resample('D')
